# %% [markdown]
# ## Create dataframe from sign_props.json file

# %%
import json
import pandas as pd

data_dict = {}
columns = []
with open('sign_props.json') as json_file:
    data = json.load(json_file)    
    #print(data)
    row_index = 1
    for attr in data[0]:
        columns.append(attr)
    for record in data:
        row = []
        for attr in record:
            row.append(record[attr])
        data_dict[row_index] = row
        row_index += 1
        
#print(data_dict)
df = pd.DataFrame.from_dict(data_dict, orient='index', columns=columns)
df
# Out:
#       index             EntryID             LemmaID      Code  \
# 1         0        &=arms-cross        &=arms-cross  J_01_098
# 2         1              &=clap                None  J_02_076
# 3         2             &=clasp             $=clasp  J_01_032
# 4         3        &=cover-ears        &=cover-ears  J_03_047
# 5         4        &=raise-hand        &=raise-hand  H_02_048
# 6         5              &=sigh              &=sigh  H_03_086
# 7         6            1_dollar            1_dollar  C_02_025
# 8         7           5_dollars           5_dollars  B_01_062
# 9         8              8_hour              8_hour  C_02_055
# 10        9            9_oclock            9_oclock  C_02_080
# 11       10          a-line_bob          a-line_bob  K_03_127
# 12       11        a_little_bit        a_little_bit  H_03_025
# 13       12          abbreviate          abbreviate  G_01_040
# 14       13             about_1               about  B_02_072
# 15       14             about_2               about  B_02_003
# 16       15  absolutely_nothing  absolutely_nothing  J_01_027
# 17       16              accent              accent  E_01_073
# 18       17              accept              accept  H_02_042
# 19       18              access              access  H_02_086
# 20       19            accident            accident  B_02_059
# 21       20          accomplish          accomplish  C_02_085
# 22       21           accordion           accordion  F_02_048
# 23       22          accountant          accountant  A_03_044
# 24       23             acquire             acquire  H_01_034
# 25       24                 act                 act  B_02_038
# 26       25              action              action  C_01_026
# 27       26               actor               actor  A_03_047
# 28       27                 add                 add  E_02_030
# 29       28              addict              addict  H_02_073
# 30       29             address             address  D_01_016
# ...     ...                 ...                 ...       ...
# 2739   2738          wristwatch          wristwatch  B_01_063
# 2740   2739        wristwatch_2        wristwatch_2  K_03_044
# 2741   2740        wristwatch_3        wristwatch_3  K_01_054
# 2742   2741               write               write  D_01_051
# 2743   2742       write_on_wall       write_on_wall  G_02_087
# 2744   2743             wrong_1               wrong  B_01_055
# 2745   2744             wrong_2               wrong  C_03_050
# 2746   2745              yawn_1              yawn_1  F_02_079
# 2747   2746              yawn_2              yawn_2  K_02_048
# 2748   2747              yawn_3              yawn_3  K_03_009
# 2749   2748              yawn_4              yawn_4  K_01_110
# 2750   2749                 yay                 yay  J_01_030
# 2751   2750                yeah                yeah  D_01_058
# 2752   2751                year                year  B_02_015
# 2753   2752              yellow              yellow  D_01_020
# 2754   2753                 yes                 yes  G_03_074
# 2755   2754           yesterday           yesterday  D_01_024
# 2756   2755                 you                 you  D_02_065
# 2757   2756               young               young  D_03_013
# 2758   2757           youngster                None  J_03_041
# 2759   2758                your                your  F_01_052
# 2760   2759            yourself            yourself  E_02_081
# 2761   2760                yoyo                yoyo  H_03_016
# 2762   2761               yucky               yucky  E_01_011
# 2763   2762               zebra               zebra  G_02_003
# 2764   2763                zero                zero  D_03_036
# 2765   2764              zipper              zipper  D_01_034
# 2766   2765                 zoo                 zoo  E_03_042
# 2767   2766             zoom_in             zoom_in  B_02_056
# 2768   2767            zoom_off            zoom_off  D_01_057
#
#       SignFrequency(M)  SignFrequency(SD)  SignFrequency(Z)  SignFrequency(N)  \
# 1                3.467              2.177            -0.458              30.0
# 2                3.867                NaN            -0.127               NaN
# 3                2.308              1.644            -1.129              29.0
# 4                2.280              1.646            -1.163              28.0
# 5                5.154              1.891             0.544              28.0
# 6                3.931              1.751            -0.196              30.0
# 7                3.034              1.500            -0.775              29.0
# 8                5.120              1.716             0.302              25.0
# 9                4.267              1.574            -0.043              30.0
# 10               4.133              1.592            -0.126              30.0
# 11               4.273              1.804            -0.198              25.0
# 12               2.963              2.028            -0.762              28.0
# 13               5.444              1.528             0.669              27.0
# 14               5.480              1.475             0.523              25.0
# 15               3.522              1.534            -0.762              23.0
# 16               2.957              1.821            -0.686              30.0
# 17               3.094              1.594            -0.681              35.0
# 18               5.500              1.072             0.812              28.0
# 19               5.036              1.170             0.527              28.0
# 20               4.120              1.833            -0.326              25.0
# 21               4.467              1.456             0.047              30.0
# 22               1.737              1.284            -1.423              27.0
# 23               3.240              1.832            -0.381              25.0
# 24               5.250              1.295             0.676              28.0
# 25               4.280              1.208            -0.214              25.0
# 26               4.533              1.383             0.075              30.0
# 27               4.440              1.635             0.230              25.0
# 28               5.188              1.203             0.520              32.0
# 29               4.250              1.378             0.101              28.0
# 30               4.889              1.476             0.410              27.0
# ...                ...                ...               ...               ...
# 2739             3.840              1.841            -0.492              25.0
# 2740             5.000              1.865             0.387              25.0
# 2741             5.185              1.665             0.584              27.0
# 2742             5.593              1.083             0.785              27.0
# 2743             3.385              1.722            -0.360              27.0
# 2744             6.080              1.077             0.860              25.0
# 2745             5.667              1.061             0.786              30.0
# 2746             3.481              1.827            -0.396              27.0
# 2747             3.450              2.114            -0.781              25.0
# 2748             3.840              2.173            -0.157              25.0
# 2749             4.520              1.917             0.120              27.0
# 2750             6.067              1.461             1.105              30.0
# 2751             5.704              1.815             0.861              27.0
# 2752             5.440              1.474             0.496              25.0
# 2753             4.481              1.312             0.189              27.0
# 2754             6.885              0.431             1.508              27.0
# 2755             5.889              1.121             0.974              27.0
# 2756             6.889              0.424             1.566              27.0
# 2757             4.962              1.113             0.475              26.0
# 2758             2.625                NaN            -0.939               NaN
# 2759             6.222              1.528             1.076              27.0
# 2760             5.250              1.545             0.527              32.0
# 2761             1.808              1.132            -1.431              28.0
# 2762             4.429              1.899             0.086              35.0
# 2763             2.556              1.649            -0.933              27.0
# 2764             4.192              1.415             0.051              26.0
# 2765             3.148              1.610            -0.556              27.0
# 2766             3.533              1.776            -0.346              30.0
# 2767             3.958              1.781            -0.443              24.0
# 2768             4.333              1.271             0.098              27.0
#
#       PercentUnknown  SignFrequency(M-Native)      ...        \
# 1                0.0                    3.400      ...
# 2                NaN                      NaN      ...
# 3                0.0                    2.267      ...
# 4                0.0                    2.167      ...
# 5                0.0                    5.500      ...
# 6                0.0                    3.267      ...
# 7                0.0                    2.944      ...
# 8                0.0                    5.214      ...
# 9                0.0                    4.444      ...
# 10               0.0                    4.778      ...
# 11               0.0                    4.500      ...
# 12               0.0                    3.000      ...
# 13               0.0                    5.250      ...
# 14               0.0                    5.500      ...
# 15               8.0                    3.417      ...
# 16               0.0                    2.833      ...
# 17               0.0                    2.750      ...
# 18               0.0                    5.786      ...
# 19               0.0                    5.214      ...
# 20               0.0                    4.071      ...
# 21               0.0                    4.611      ...
# 22               0.0                    1.875      ...
# 23               0.0                    3.067      ...
# 24               0.0                    5.286      ...
# 25               0.0                    4.286      ...
# 26               0.0                    4.944      ...
# 27               0.0                    4.533      ...
# 28               0.0                    5.000      ...
# 29               0.0                    4.571      ...
# 30               0.0                    5.125      ...
# ...              ...                      ...      ...
# 2739             0.0                    3.786      ...
# 2740             0.0                    4.364      ...
# 2741             0.0                    4.273      ...
# 2742             0.0                    5.875      ...
# 2743             0.0                    3.750      ...
# 2744             0.0                    6.286      ...
# 2745             0.0                    5.667      ...
# 2746             0.0                    3.429      ...
# 2747             0.0                    2.875      ...
# 2748             0.0                    3.000      ...
# 2749             0.0                    4.364      ...
# 2750             0.0                    6.133      ...
# 2751             0.0                    5.875      ...
# 2752             0.0                    5.714      ...
# 2753             0.0                    4.313      ...
# 2754             0.0                    7.000      ...
# 2755             0.0                    6.000      ...
# 2756             0.0                    7.000      ...
# 2757             0.0                    5.188      ...
# 2758             NaN                      NaN      ...
# 2759             0.0                    6.357      ...
# 2760             0.0                    5.400      ...
# 2761             0.0                    1.769      ...
# 2762             0.0                    4.867      ...
# 2763             0.0                    2.917      ...
# 2764             0.0                    4.313      ...
# 2765             0.0                    2.875      ...
# 2766             0.0                    3.857      ...
# 2767             4.0                    3.929      ...
# 2768             0.0                    4.063      ...
#
#       MinorLocation.2.0  SecondMinorLocation.2.0  Contact.2.0  \
# 1                  None                     None          NaN
# 2                  None                     None          NaN
# 3          FingerRadial             FingerRadial          1.0
# 4               Neutral                  Neutral          1.0
# 5                  None                     None          NaN
# 6                  None                     None          NaN
# 7            FingerBack                 HandAway          1.0
# 8               Neutral                     None          0.0
# 9           FingerFront                     Palm          1.0
# 10            WristBack                     None          1.0
# 11             HeadAway                 HeadAway          0.0
# 12              Neutral                     None          0.0
# 13         FingerRadial                 HandAway          1.0
# 14             HandAway                FingerTip          1.0
# 15             HandAway                FingerTip          1.0
# 16                Mouth                     None          1.0
# 17                 Neck                     None          1.0
# 18             TorsoTop                     None          1.0
# 19                 Palm                 HandAway          1.0
# 20              Neutral                  Neutral          1.0
# 21             HeadAway                 HeadAway          0.0
# 22              Neutral                  Neutral          0.0
# 23                 Palm                     None          1.0
# 24              Neutral                  Neutral          0.0
# 25             TorsoTop                 TorsoTop          1.0
# 26              Neutral                  Neutral          0.0
# 27             TorsoTop                 BodyAway          1.0
# 28             HandAway              FingerUlnar          1.0
# 29                Mouth                     None          1.0
# 30             TorsoMid                 TorsoTop          1.0
# ...                 ...                      ...          ...
# 2739          WristBack                     None          1.0
# 2740          WristBack                     None          1.0
# 2741          WristBack                     None          1.0
# 2742               Palm                 HandAway          1.0
# 2743            Neutral                  Neutral          0.0
# 2744               Chin                     None          1.0
# 2745               Chin                     None          1.0
# 2746              Mouth                     None          1.0
# 2747         FingerBack                 HandAway          1.0
# 2748              Mouth                 HeadAway          1.0
# 2749              Mouth                     None          1.0
# 2750           HeadAway                     None          0.0
# 2751            Neutral                     None          0.0
# 2752            Neutral                  Neutral          1.0
# 2753            Neutral                     None          0.0
# 2754            Neutral                     None          0.0
# 2755               Chin                CheekNose          1.0
# 2756            Neutral                     None          0.0
# 2757            Neutral                     None          0.0
# 2758              Waist                 BodyAway          1.0
# 2759            Neutral                  Neutral          0.0
# 2760       FingerRadial                     None          1.0
# 2761            Neutral                  Neutral          0.0
# 2762            Neutral                  Neutral          0.0
# 2763           TorsoTop                 TorsoMid          1.0
# 2764            Neutral                  Neutral          0.0
# 2765              Waist                 TorsoTop          0.0
# 2766            Neutral                  Neutral          0.0
# 2767            Neutral                  Neutral          1.0
# 2768         FingerBack                 HandAway          0.0
#
#          NonDominantHandshape.2.0  UlnarRotation.2.0  Batch  Item  List  \
# 1                            None                NaN      J  98.0   1.0
# 2                            None                NaN      J  76.0   2.0
# 3                               1                0.0      J  32.0   1.0
# 4                          open_b                0.0      J  47.0   3.0
# 5                            None                NaN      H  48.0   2.0
# 6                            None                NaN      H  86.0   3.0
# 7                               B                0.0      C  25.0   2.0
# 8                            None                1.0      B  62.0   1.0
# 9                               B                0.0      C  55.0   2.0
# 10                           None                0.0      C  80.0   2.0
# 11                         flat_b                1.0   None   NaN   NaN
# 12                           None                0.0      H  25.0   3.0
# 13    DominanceConditionViolation                1.0      G  40.0   1.0
# 14                              1                1.0      B  72.0   2.0
# 15                              O                1.0      B   3.0   2.0
# 16                           None                0.0      J  27.0   1.0
# 17                           None                1.0      E  73.0   1.0
# 18                   flatspread_5                0.0      H  42.0   2.0
# 19                              B                0.0      H  86.0   2.0
# 20                              5                0.0      B  59.0   2.0
# 21                              1                1.0      C  85.0   2.0
# 22                              s                0.0      F  48.0   2.0
# 23                              B                0.0      A  44.0   3.0
# 24                              8                0.0      H  34.0   1.0
# 25                              a                0.0      B  38.0   2.0
# 26                              c                0.0      C  26.0   1.0
# 27                              a                0.0      A  47.0   3.0
# 28    DominanceConditionViolation                0.0      E  30.0   2.0
# 29                           None                0.0      H  73.0   2.0
# 30                              a                0.0      D  16.0   1.0
# ...                           ...                ...    ...   ...   ...
# 2739                         None                0.0      B  63.0   1.0
# 2740                         None                0.0   None   NaN   NaN
# 2741                         None                0.0   None   NaN   NaN
# 2742                            B                0.0      D  51.0   1.0
# 2743                         None                0.0      G  87.0   2.0
# 2744                         None                0.0      B  55.0   1.0
# 2745                         None                0.0      C  50.0   3.0
# 2746                         None                0.0      F  79.0   2.0
# 2747  DominanceConditionViolation                0.0   None   NaN   NaN
# 2748  DominanceConditionViolation                0.0   None   NaN   NaN
# 2749                         None                0.0   None   NaN   NaN
# 2750                            5                1.0      J  30.0   1.0
# 2751                         None                0.0      D  58.0   1.0
# 2752                            s                0.0      B  15.0   2.0
# 2753                         None                1.0      D  20.0   1.0
# 2754                         None                0.0      G  74.0   3.0
# 2755                         None                0.0      D  24.0   1.0
# 2756                         None                0.0      D  65.0   2.0
# 2757                         None                1.0      D  13.0   3.0
# 2758                       open_b                0.0      J  41.0   3.0
# 2759                         None                0.0      F  52.0   1.0
# 2760                            1                0.0      E  81.0   2.0
# 2761                         None                0.0      H  16.0   3.0
# 2762                            1                0.0      E  11.0   1.0
# 2763                       flat_4                0.0      G   3.0   2.0
# 2764                         None                0.0      D  36.0   3.0
# 2765  DominanceConditionViolation                0.0      D  34.0   1.0
# 2766                         None                0.0      E  42.0   3.0
# 2767                            s                0.0      B  56.0   2.0
# 2768                            1                0.0      D  57.0   1.0
#
#       bglm_aoa  empirical_aoa
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# 5          NaN            NaN
# 6          NaN            NaN
# 7          NaN            NaN
# 8          NaN            NaN
# 9          NaN            NaN
# 10         NaN            NaN
# 11         NaN            NaN
# 12         NaN            NaN
# 13         NaN            NaN
# 14         NaN            NaN
# 15        61.0           35.0
# 16         NaN            NaN
# 17         NaN            NaN
# 18         NaN            NaN
# 19         NaN            NaN
# 20         NaN            NaN
# 21         NaN            NaN
# 22         NaN            NaN
# 23         NaN            NaN
# 24         NaN            NaN
# 25         NaN            NaN
# 26         NaN            NaN
# 27         NaN            NaN
# 28         NaN            NaN
# 29         NaN            NaN
# 30         NaN            NaN
# ...        ...            ...
# 2739      39.0           34.0
# 2740       NaN            NaN
# 2741       NaN            NaN
# 2742      31.0           28.0
# 2743       NaN            NaN
# 2744       NaN            NaN
# 2745       NaN            NaN
# 2746       NaN            NaN
# 2747       NaN            NaN
# 2748       NaN            NaN
# 2749       NaN            NaN
# 2750       NaN            NaN
# 2751       NaN            NaN
# 2752      57.0           45.0
# 2753      27.0           28.0
# 2754      24.0           19.0
# 2755      49.0           36.0
# 2756      26.0           16.0
# 2757       NaN            NaN
# 2758       NaN            NaN
# 2759      26.0           28.0
# 2760      56.0           47.0
# 2761       NaN            NaN
# 2762      45.0           21.0
# 2763       NaN            NaN
# 2764       NaN            NaN
# 2765      29.0           28.0
# 2766      39.0           28.0
# 2767       NaN            NaN
# 2768       NaN            NaN
#
# [2768 rows x 69 columns]

# %% [markdown]
# ## Finding categorical and range attributes

# %%
numerical_attr = list(df.select_dtypes(include=['float', 'int']).columns)
categorical_attr = []
for column in list(df.columns):
    if column not in numerical_attr:
        categorical_attr.append(column)   
print(numerical_attr)
print(categorical_attr)
# Out:
# ['index', 'SignFrequency(M)', 'SignFrequency(SD)', 'SignFrequency(Z)', 'SignFrequency(N)', 'PercentUnknown', 'SignFrequency(M-Native)', 'SignFrequency(SD-Native)', 'SignFreq(Z-native)', 'SignFrequency(N-Native)', 'PercentUnknown(Native)', 'PercentGlossAgreement', 'PercentGlossAgreement(Native)', 'Iconicity(M)', 'Iconicity(SD)', 'Iconicity(Z)', 'Iconicity(N)', 'SubtLexUSLog10WF', 'SignOnset(ms)', 'SignOffset(ms)', 'SignLength(ms)', 'ClipLength(ms)', 'MinimalNeighborhoodDensity', 'MaximalNeighborhoodDensity', 'Parameter-BasedNeighborhoodDensity', 'D.Iconicity(M) all', 'D.Iconicity(SD) all', 'D.Iconicity(N) all', 'D.Iconicity(Z) all', 'D.Iconicity(M) native', 'D.Iconicity(SD) native', 'D.Iconicity(N) native', 'D.Iconicity(Z) native', 'Complexity', 'RightWristX', 'RightWristcentroidY', 'DistanceRightWristCentroid2Nose', 'Initialized.2.0', 'FingerspelledLoanSign.2.0', 'Compound.2.0', 'NumberOfMorphemes.2.0', 'MarkedHandshape.2.0', 'FlexionChange.2.0', 'Spread.2.0', 'SpreadChange.2.0', 'ThumbContact.2.0', 'Contact.2.0', 'UlnarRotation.2.0', 'Item', 'List', 'bglm_aoa', 'empirical_aoa']
# ['EntryID', 'LemmaID', 'Code', 'Iconicity_ID', 'LexicalClass', 'IconicityType', 'Handshape.2.0', 'SelectedFingers.2.0', 'Flexion.2.0', 'ThumbPosition.2.0', 'SignType.2.0', 'Movement.2.0', 'MajorLocation.2.0', 'MinorLocation.2.0', 'SecondMinorLocation.2.0', 'NonDominantHandshape.2.0', 'Batch']

# %% [markdown]
# ## Find the constraints of the attributes
# ### For categorical attributes we find all the possible values and for numberical attributes we find min and max

# %%
import math 
import pprint

constraints = {}
for attr in categorical_attr:
    if attr not in ['EntryID', 'LemmaID', 'Code', 'Iconicity_ID']:
        columnsData = df.loc[ : , attr ]
        constraints[attr] = list(set(list(columnsData)))
        
for attr in numerical_attr:    
    #drop nan values 
    columnsData = df.loc[ : , attr ].dropna()
    constraints[attr] = {}  
    #print(math.floor(min(list(columnsData))), math.ceil(max(list(columnsData))), attr)
    constraints[attr]['min'] = math.floor(min(list(columnsData)))
    constraints[attr]['max'] = math.ceil(max(list(columnsData)))

pprint.pprint(constraints)
# Out:
# {'Batch': ['C', 'D', 'E', 'B', None, 'F', 'A', 'J', 'G', 'H'],
#  'ClipLength(ms)': {'max': 3737, 'min': 901},
#  'Complexity': {'max': 6, 'min': 0},
#  'Compound.2.0': {'max': 1, 'min': 0},
#  'Contact.2.0': {'max': 1, 'min': 0},
#  'D.Iconicity(M) all': {'max': 7, 'min': 1},
#  'D.Iconicity(M) native': {'max': 7, 'min': 1},
#  'D.Iconicity(N) all': {'max': 31, 'min': 26},
#  'D.Iconicity(N) native': {'max': 22, 'min': 18},
#  'D.Iconicity(SD) all': {'max': 3, 'min': 0},
#  'D.Iconicity(SD) native': {'max': 3, 'min': 0},
#  'D.Iconicity(Z) all': {'max': 3, 'min': -2},
#  'D.Iconicity(Z) native': {'max': 3, 'min': -2},
#  'DistanceRightWristCentroid2Nose': {'max': 2193, 'min': 1002},
#  'FingerspelledLoanSign.2.0': {'max': 1, 'min': 0},
#  'Flexion.2.0': ['Curved',
#                  'Stacked',
#                  'FullyClosed',
#                  'Flat',
#                  'FullyOpen',
#                  None,
#                  'Crossed',
#                  'Bent'],
#  'FlexionChange.2.0': {'max': 1, 'min': 0},
#  'Handshape.2.0': ['curved_v',
#                    'i',
#                    'closed_e',
#                    'flat_b',
#                    'closed_b',
#                    'y',
#                    'open_8',
#                    's',
#                    'flat_v',
#                    'o',
#                    'open_h',
#                    'flatspread_5',
#                    'flat_1',
#                    'f',
#                    '4',
#                    '8',
#                    'e',
#                    'goody_goody',
#                    'w',
#                    'flat_h',
#                    'horns',
#                    '3',
#                    'baby_o',
#                    'k',
#                    'bent_l',
#                    '7',
#                    'p',
#                    'r',
#                    'curved_5',
#                    'open_b',
#                    'curved_b',
#                    'l',
#                    'curved_4',
#                    'flat_m',
#                    'stacked_5',
#                    'spread_e',
#                    'bent_v',
#                    None,
#                    'flat_o',
#                    'trip',
#                    'v',
#                    'ily',
#                    'c',
#                    'd',
#                    'bent_1',
#                    '1',
#                    'flat_4',
#                    'g',
#                    'curved_l',
#                    'flat_ily',
#                    'open_e',
#                    'spread_open_e',
#                    'flat_n',
#                    'flat_horns',
#                    '5',
#                    'a',
#                    'curved_1',
#                    'h',
#                    'curved_h'],
#  'Iconicity(M)': {'max': 9, 'min': 1},
#  'Iconicity(N)': {'max': 403, 'min': 2},
#  'Iconicity(SD)': {'max': 3, 'min': 0},
#  'Iconicity(Z)': {'max': 3, 'min': -2},
#  'IconicityType': ['Perceptual', None, 'Both', 'Pantomimic', 'Arbitrary'],
#  'Initialized.2.0': {'max': 1, 'min': 0},
#  'Item': {'max': 110, 'min': 1},
#  'LexicalClass': ['Name',
#                   'Verb ',
#                   'Noun ',
#                   'Adjective',
#                   None,
#                   'Gesture',
#                   'Adverb',
#                   'Noun/Adjective',
#                   'Minor',
#                   'Number',
#                   'Verb',
#                   'Noun'],
#  'List': {'max': 3, 'min': 1},
#  'MajorLocation.2.0': ['Other', 'Body', 'Arm', None, 'Head', 'Neutral', 'Hand'],
#  'MarkedHandshape.2.0': {'max': 1, 'min': 0},
#  'MaximalNeighborhoodDensity': {'max': 118, 'min': 0},
#  'MinimalNeighborhoodDensity': {'max': 943, 'min': 352},
#  'MinorLocation.2.0': ['Forehead',
#                        'FingerUlnar',
#                        'ForearmBack',
#                        'Chin',
#                        'FingerRadial',
#                        'FingerFront',
#                        'Shoulder',
#                        'ForearmFront',
#                        'TorsoTop',
#                        'FingerBack',
#                        'Mouth',
#                        'UpperArm',
#                        'HeadAway',
#                        'UnderChin',
#                        'Neck',
#                        'ArmAway',
#                        'UpperLip',
#                        'PalmBack',
#                        'Palm',
#                        'ElbowBack',
#                        'HandAway',
#                        'WristFront',
#                        'TorsoBottom',
#                        'Other',
#                        'CheekNose',
#                        None,
#                        'Waist',
#                        'HeadTop',
#                        'WristBack',
#                        'Clavicle',
#                        'Hips',
#                        'ForearmUlnar',
#                        'FingerTip',
#                        'Eye',
#                        'Heel',
#                        'BodyAway',
#                        'TorsoMid',
#                        'Neutral'],
#  'Movement.2.0': ['Curved',
#                   'Straight',
#                   'Other',
#                   None,
#                   'Circular',
#                   'None',
#                   'BackAndForth',
#                   'X-shaped',
#                   'Z-shaped'],
#  'NonDominantHandshape.2.0': ['curved_v',
#                               'i',
#                               'flat_b',
#                               'closed_b',
#                               'y',
#                               'open_8',
#                               's',
#                               'flat_v',
#                               'o',
#                               'DominanceConditionViolation',
#                               'open_h',
#                               'flatspread_5',
#                               'flat_1',
#                               'f',
#                               '4',
#                               '8',
#                               'e',
#                               'w',
#                               'S',
#                               'flat_h',
#                               'horns',
#                               'A',
#                               '3',
#                               'baby_o',
#                               'bent_l',
#                               'O',
#                               'p',
#                               'curved_5',
#                               'open_b',
#                               'l',
#                               'r',
#                               'curved_b',
#                               'SymmetryViolation',
#                               'flat_m',
#                               'stacked_5',
#                               'curved_4',
#                               'bent_v',
#                               'C',
#                               None,
#                               'flat_o',
#                               'v',
#                               'Lax',
#                               'c',
#                               'ily',
#                               'bent_1',
#                               '1',
#                               'flat_4',
#                               'g',
#                               'curved_l',
#                               'open_e',
#                               'spread_open_e',
#                               'B',
#                               'flat_horns',
#                               '5',
#                               'a',
#                               'curved_1',
#                               'h'],
#  'NumberOfMorphemes.2.0': {'max': 6, 'min': 1},
#  'Parameter-BasedNeighborhoodDensity': {'max': 32, 'min': 0},
#  'PercentGlossAgreement': {'max': 100, 'min': 0},
#  'PercentGlossAgreement(Native)': {'max': 100, 'min': 0},
#  'PercentUnknown': {'max': 44, 'min': 0},
#  'PercentUnknown(Native)': {'max': 50, 'min': 0},
#  'RightWristX': {'max': 1772, 'min': 837},
#  'RightWristcentroidY': {'max': 1473, 'min': 207},
#  'SecondMinorLocation.2.0': ['Forehead',
#                              'FingerUlnar',
#                              'ForearmBack',
#                              'Chin',
#                              'FingerFront',
#                              'FingerRadial',
#                              'ForearmFront',
#                              'Shoulder',
#                              'TorsoTop',
#                              'FingerBack',
#                              'Mouth',
#                              'UpperArm',
#                              'HeadAway',
#                              'UnderChin',
#                              'Neck',
#                              'ArmAway',
#                              'UpperLip',
#                              'PalmBack',
#                              'Palm',
#                              'ElbowBack',
#                              'HandAway',
#                              'TorsoBottom',
#                              'Other',
#                              'OtherAway',
#                              'CheekNose',
#                              None,
#                              'Waist',
#                              'Clavicle',
#                              'Hips',
#                              'HeadTop',
#                              'FingerTip',
#                              'ForearmUlnar',
#                              'Heel',
#                              'Eye',
#                              'BodyAway',
#                              'TorsoMid',
#                              'Neutral',
#                              'ForearmRadial'],
#  'SelectedFingers.2.0': ['imr',
#                          'i',
#                          'imrp',
#                          'p',
#                          'mrp',
#                          None,
#                          'ip',
#                          'im',
#                          'mr',
#                          'm',
#                          'r',
#                          't',
#                          'imp'],
#  'SignFreq(Z-native)': {'max': 2, 'min': -3},
#  'SignFrequency(M)': {'max': 7, 'min': 0},
#  'SignFrequency(M-Native)': {'max': 7, 'min': 1},
#  'SignFrequency(N)': {'max': 50, 'min': 15},
#  'SignFrequency(N-Native)': {'max': 22, 'min': 7},
#  'SignFrequency(SD)': {'max': 3, 'min': 0},
#  'SignFrequency(SD-Native)': {'max': 3, 'min': 0},
#  'SignFrequency(Z)': {'max': 2, 'min': -3},
#  'SignLength(ms)': {'max': 2603, 'min': -434},
#  'SignOffset(ms)': {'max': 3103, 'min': 100},
#  'SignOnset(ms)': {'max': 1668, 'min': 67},
#  'SignType.2.0': ['SymmetricalOrAlternating',
#                   None,
#                   'AsymmetricalSameHandshape',
#                   'AsymmetricalDifferentHandshape',
#                   'DominanceViolation',
#                   'SymmetryViolation',
#                   'OneHanded'],
#  'Spread.2.0': {'max': 1, 'min': 0},
#  'SpreadChange.2.0': {'max': 1, 'min': 0},
#  'SubtLexUSLog10WF': {'max': 7, 'min': 0},
#  'ThumbContact.2.0': {'max': 1, 'min': 0},
#  'ThumbPosition.2.0': ['Open', 'Closed', None],
#  'UlnarRotation.2.0': {'max': 1, 'min': 0},
#  'bglm_aoa': {'max': 67, 'min': 14},
#  'empirical_aoa': {'max': 60, 'min': 9},
#  'index': {'max': 2767, 'min': 0}}

# %% [markdown]
# ## Store attribute constraints in a json file

# %%
import json

with open('constraints.json', 'w') as fp:
    json.dump(constraints, fp)
