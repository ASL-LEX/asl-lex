# %%
import pandas as pd

# %%
sign_df = pd.read_csv('new-data/signdata_latest.csv')
print(sign_df.shape)
sign_df.head()
# Out:
# (2768, 155)
#         EntryID       LemmaID      Code  \
# 0  &=arms-cross  &=arms-cross  J_01_098
# 1        &=clap           NaN  J_02_076
# 2       &=clasp       $=clasp  J_01_032
# 3  &=cover-ears  &=cover-ears  J_03_047
# 4  &=raise-hand  &=raise-hand  H_02_048
#
#                                        YouTube Video Vimeo Video  \
# 0  <iframe width="280" height="158" src="https://...         NaN
# 1  <iframe width="280" height="158" src="https://...         NaN
# 2  <iframe width="280" height="158" src="https://...         NaN
# 3  <iframe width="280" height="158" src="https://...         NaN
# 4  <iframe width="280" height="158" src="https://...         NaN
#
#    SignFrequency(M)  SignFrequency(SD)  SignFrequency(Z)  SignFrequency(N)  \
# 0             3.467              2.177            -0.458              30.0
# 1             3.867                NaN            -0.127               NaN
# 2             2.308              1.644            -1.129              29.0
# 3             2.280              1.646            -1.163              28.0
# 4             5.154              1.891             0.544              28.0
#
#    PercentUnknown  ...  MinorLocationM6.2.0  SecondMinorLocationM6.2.0  \
# 0             0.0  ...                  NaN                        NaN
# 1             NaN  ...                  NaN                        NaN
# 2             0.0  ...                  NaN                        NaN
# 3             0.0  ...                  NaN                        NaN
# 4             0.0  ...                  NaN                        NaN
#
#    ContactM6.2.0  NonDominantHandshapeM6.2.0  UlnarRotationM6.2.0  Batch  \
# 0            NaN                         NaN                  NaN      J
# 1            NaN                         NaN                  NaN      J
# 2            NaN                         NaN                  NaN      J
# 3            NaN                         NaN                  NaN      J
# 4            NaN                         NaN                  NaN      H
#
#    Item  List  bglm_aoa  empirical_aoa
# 0  98.0   1.0       NaN            NaN
# 1  76.0   2.0       NaN            NaN
# 2  32.0   1.0       NaN            NaN
# 3  47.0   3.0       NaN            NaN
# 4  48.0   2.0       NaN            NaN
#
# [5 rows x 155 columns]

# %%
pd.Series(sign_df.columns)
test_df = sign_df
test_df = test_df[test_df.columns.drop(list(test_df.filter(regex='M..2.0|Video')))]
test_df.columns
# Out:
# Index(['EntryID', 'LemmaID', 'Code', 'SignFrequency(M)', 'SignFrequency(SD)',
#        'SignFrequency(Z)', 'SignFrequency(N)', 'PercentUnknown',
#        'SignFrequency(M-Native)', 'SignFrequency(SD-Native)',
#        'SignFreq(Z-native)', 'SignFrequency(N-Native)',
#        'PercentUnknown(Native)', 'PercentGlossAgreement',
#        'PercentGlossAgreement(Native)', 'Iconicity(M)', 'Iconicity(SD)',
#        'Iconicity(Z)', 'Iconicity(N)', 'Iconicity_ID', 'SubtLexUSLog10WF',
#        'LexicalClass', 'SignOnset(ms)', 'SignOffset(ms)', 'SignLength(ms)',
#        'ClipLength(ms)', 'MinimalNeighborhoodDensity',
#        'MaximalNeighborhoodDensity', 'Parameter-BasedNeighborhoodDensity',
#        'D.Iconicity(M) all', 'D.Iconicity(SD) all', 'D.Iconicity(N) all',
#        'D.Iconicity(Z) all', 'D.Iconicity(M) native', 'D.Iconicity(SD) native',
#        'D.Iconicity(N) native', 'D.Iconicity(Z) native', 'Complexity',
#        'RightWristX', 'RightWristcentroidY', 'DistanceRightWristCentroid2Nose',
#        'IconicityType', 'Initialized.2.0', 'FingerspelledLoanSign.2.0',
#        'Compound.2.0', 'NumberOfMorphemes.2.0', 'Handshape.2.0',
#        'MarkedHandshape.2.0', 'SelectedFingers.2.0', 'Flexion.2.0',
#        'FlexionChange.2.0', 'Spread.2.0', 'SpreadChange.2.0',
#        'ThumbPosition.2.0', 'ThumbContact.2.0', 'SignType.2.0', 'Movement.2.0',
#        'MajorLocation.2.0', 'MinorLocation.2.0', 'SecondMinorLocation.2.0',
#        'Contact.2.0', 'NonDominantHandshape.2.0', 'UlnarRotation.2.0', 'Batch',
#        'Item', 'List', 'bglm_aoa', 'empirical_aoa'],
#       dtype='object')

# %%
test_df.reset_index().to_json('new-data/sign_props.json', orient='records')
# sign_df.to_json('sign_props.json')
