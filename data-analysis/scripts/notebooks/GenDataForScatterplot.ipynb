# %%
import pandas as pd
pd.options.display.max_rows = 3000
pd.options.display.max_columns = 160

# %% [markdown]
# # Current Data

# %%
df = pd.read_csv('../data/generated-data/default-nd.csv')

# %%
df.head()
# Out:
#       EntryID     LemmaID      Code Batch  List  Item  \
# 0    1_dollar    1_dollar  C_02_025     C   2.0  25.0
# 1   5_dollars   5_dollars  B_01_062     B   1.0  62.0
# 2      8_hour      8_hour  C_02_055     C   2.0  55.0
# 3    9_oclock    9_oclock  C_02_080     C   2.0  80.0
# 4  a-line_bob  a-line_bob  K_03_127     K   NaN   NaN
#
#                                        YouTube Video  \
# 0  <iframe width="280" height="158" src="https://...
# 1  <iframe width="280" height="158" src="https://...
# 2  <iframe width="280" height="158" src="https://...
# 3  <iframe width="280" height="158" src="https://...
# 4                                                NaN
#
#                                       VimeoVideoHTML  \
# 0  <iframe src=https://player.vimeo.com/video/345...
# 1  <iframe src=https://player.vimeo.com/video/344...
# 2  <iframe src="https://player.vimeo.com/video/34...
# 3  <iframe src=https://player.vimeo.com/video/345...
# ...

# %%
list(df.columns)
# Out:
# ['EntryID',
#  'LemmaID',
#  'Code',
#  'Batch',
#  'List',
#  'Item',
#  'YouTube Video',
#  'VimeoVideoHTML',
#  'VimeoVideo',
#  'SubtLexUSLog10WF',
#  'SignFrequency(M)',
#  'SignFrequency(SD)',
#  'SignFrequency(Z)',
#  'SignFrequency(N)',
#  'SignFrequency(M-Native)',
#  'SignFrequency(SD-Native)',
#  'SignFreq(Z-native)',
#  'SignFrequency(N-Native)',
#  'SignFrequency(M-Nonnative)',
#  'SignFrequency(SD-Nonnative)',
#  'SignFrequency(N-Nonnative)',
#  'SignFreq(Z-Nonnative)',
#  'DominantTranslation',
#  'NondominantTranslation',
#  'PercentUnknown',
#  'PercentGlossAgreement',
#  'PercentUnknown(Native)',
#  'PercentGlossAgreement(Native)',
#  'PercentUnknown(Nonnative)',
#  'PercentGlossAgreement(Nonnative)',
#  'Iconicity(M)',
#  'Iconicity(SD)',
#  'Iconicity(Z)',
#  'Iconicity(N)',
#  'Iconicity_ID',
#  'IconicityType',
#  'D.Iconicity(M) all',
#  'D.Iconicity(SD) all',
#  'D.Iconicity(N) all',
#  'D.Iconicity(Z) all',
#  'D.Iconicity(M) native',
# ...

# %%
df["LexicalClass"].value_counts()
# Out:
# Noun         1279
# Verb          905
# Adjective     300
# Minor         118
# Adverb         50
# Name           42
# Number         24
# Name: LexicalClass, dtype: int64

# %% [markdown]
# ## SubDataframe for scatter plotting
# ### NaN data replaced by 0

# %%
def cat2num(pd_col):
    pd_col.fillna(0)
    print(pd_col.isna().sum())
    cat_dict = {[*set(pd_col)][i]: i for i in range(len(set(pd_col))) }
    print(cat_dict)
    return cat_dict

# %%
subdf2 = df.loc[:, ['Code','EntryID', 'SignFrequency(M)', 'Iconicity(M)','Neighborhood Density 2.0']]
subdf2
# Out:
#           Code                    EntryID  SignFrequency(M)  Iconicity(M)  \
# 0     C_02_025                   1_dollar             3.034         1.074
# 1     B_01_062                  5_dollars             5.120         5.481
# 2     C_02_055                     8_hour             4.267         2.654
# 3     C_02_080                   9_oclock             4.133         2.741
# 4     K_03_127                 a-line_bob             4.273         3.769
# 5     H_03_025               a_little_bit             2.963         2.833
# 6     G_01_040                 abbreviate             5.444         1.889
# 7     B_02_072                    about_1             5.480         2.067
# 8     B_02_003                    about_2             3.522         2.133
# 9     J_01_027         absolutely_nothing             2.957         1.500
# 10    E_01_073                     accent             3.094         1.917
# 11    H_02_042                     accept             5.500         2.739
# ...

# %%
subdf2.round({'Neighborhood Density 2.0': 1})
subdf2.shape
# Out:
# (2723, 5)

# %%
ttCat = subdf2
ttCat['SignType'] = df['SignType.2.0'].replace(cat2num(df['SignType.2.0']))
# Out:
# 0
# {'OneHanded': 0, 'SymmetryViolation': 1, 'DominanceViolation': 2, 'AsymmetricalSameHandshape': 3, 'AsymmetricalDifferentHandshape': 4, 'SymmetricalOrAlternating': 5}

# %%
ttCat['LexicalClass'] = df['LexicalClass'].replace(cat2num(df['LexicalClass']))
# Out:
# 5
# {nan: 0, 'Number': 1, 'Name': 2, 'Adjective': 3, 'Verb': 4, 'Noun': 5, 'Adverb': 6, 'Minor': 7}

# %%
ttCat["LexicalClass"].value_counts()
# Out:
# 5    1279
# 4     905
# 3     300
# 7     118
# 6      50
# 2      42
# 1      24
# 0       5
# Name: LexicalClass, dtype: int64

# %%
ttCat[ttCat["LexicalClass"]==0]
# Out:
#           Code            EntryID  SignFrequency(M)  Iconicity(M)  \
# 955   J_03_034  friends_no_more_1             1.696         3.130
# 1454  K_03_048          mea_culpa             4.318         1.462
# 1567  H_01_078         news_to_me             5.040         2.000
# 1578  H_03_044        no_big_deal             5.107         4.417
# 2423  K_01_120       think_ponder             6.148         2.760
#
#       Neighborhood Density 2.0  SignType  LexicalClass
# 955                          0         0             0
# 1454                         0         4             0
# 1567                         4         5             0
# 1578                         8         5             0
# 2423                         0         0             0

# %%
# ttCat.dropna(axis=0).to_csv('subdf_ind_cat.csv')

# %%
ttCat.fillna(0).to_csv('density_subdf_ind_w_entryID.csv')

# %%
ttCat.fillna(0)
# Out:
#           Code                    EntryID  SignFrequency(M)  Iconicity(M)  \
# 0     C_02_025                   1_dollar             3.034         1.074
# 1     B_01_062                  5_dollars             5.120         5.481
# 2     C_02_055                     8_hour             4.267         2.654
# 3     C_02_080                   9_oclock             4.133         2.741
# 4     K_03_127                 a-line_bob             4.273         3.769
# 5     H_03_025               a_little_bit             2.963         2.833
# 6     G_01_040                 abbreviate             5.444         1.889
# 7     B_02_072                    about_1             5.480         2.067
# 8     B_02_003                    about_2             3.522         2.133
# 9     J_01_027         absolutely_nothing             2.957         1.500
# 10    E_01_073                     accent             3.094         1.917
# 11    H_02_042                     accept             5.500         2.739
# ...

# %%
tt = subdf2
tt['LexicalClass'] = df['LexicalClass'].replace(cat2num(df['LexicalClass']))
tt['SignType'] = df['SignType.2.0'].replace(cat2num(df['SignType.2.0']))
# Out:
# 5
# {nan: 0, 'Number': 1, 'Name': 2, 'Adjective': 3, 'Verb': 4, 'Noun': 5, 'Adverb': 6, 'Minor': 7}
# 0
# {'OneHanded': 0, 'SymmetryViolation': 1, 'DominanceViolation': 2, 'AsymmetricalSameHandshape': 3, 'AsymmetricalDifferentHandshape': 4, 'SymmetricalOrAlternating': 5}

# %%
catDict1 = cat2num(df['LexicalClass'])
catDict2 = cat2num(df['SignType.2.0'])
# Out:
# 5
# {nan: 0, 'Number': 1, 'Name': 2, 'Adjective': 3, 'Verb': 4, 'Noun': 5, 'Adverb': 6, 'Minor': 7}
# 0
# {'OneHanded': 0, 'SymmetryViolation': 1, 'DominanceViolation': 2, 'AsymmetricalSameHandshape': 3, 'AsymmetricalDifferentHandshape': 4, 'SymmetricalOrAlternating': 5}

# %%
catDict2
# Out:
# {'SymmetricalOrAlternating': 0,
#  'AsymmetricalDifferentHandshape': 1,
#  'AsymmetricalSameHandshape': 2,
#  'SymmetryViolation': 3,
#  'OneHanded': 4,
#  'DominanceViolation': 5}

# %%
tt = tt.fillna(0)
tt
# Out:
#           Code                    EntryID  SignFrequency(M)  Iconicity(M)  \
# 0     C_02_025                   1_dollar             3.034         1.074
# 1     B_01_062                  5_dollars             5.120         5.481
# 2     C_02_055                     8_hour             4.267         2.654
# 3     C_02_080                   9_oclock             4.133         2.741
# 4     K_03_127                 a-line_bob             4.273         3.769
# 5     H_03_025               a_little_bit             2.963         2.833
# 6     G_01_040                 abbreviate             5.444         1.889
# 7     B_02_072                    about_1             5.480         2.067
# 8     B_02_003                    about_2             3.522         2.133
# 9     J_01_027         absolutely_nothing             2.957         1.500
# 10    E_01_073                     accent             3.094         1.917
# 11    H_02_042                     accept             5.500         2.739
# ...

# %%
print(tt.filter(regex="Sign*", axis=1).astype('float').max())
print(tt.filter(regex="Sign*", axis=1).astype('float').min())
# Out:
# SignFrequency(M)    6.963
# SignType            5.000
# dtype: float64
# SignFrequency(M)    1.0
# SignType            0.0
# dtype: float64

# %%
print(subdf2['Iconicity(M)'].astype('float').max(), subdf2['Iconicity(M)'].astype('float').min())
# Out:
# 7.0 1.0

# %%
tt.to_csv('subdf_ind.csv')

# %%
tt['SignFrequency(M)'].dtype
# Out:
# dtype('float64')

# %%
# not used
def plot_clustered_stacked(dfall, labels=None, title="multiple stacked bar plot",  H="/", **kwargs):
    """
    Given a list of dataframes, with identical columns and index, create a clustered stacked bar plot. 
    labels is a list of the names of the dataframe, used for the legend
    title is a string for the title of the plot
    H is the hatch used for identification of the different dataframe
    """

    n_df = len(dfall)
    n_col = len(dfall[0].columns) 
    n_ind = len(dfall[0].index)
    axe = plt.subplot(111)

    for df in dfall : # for each data frame
        axe = df.plot(kind="bar",
                      linewidth=0,
                      stacked=True,
                      ax=axe,
                      legend=False,
                      grid=False,
                      **kwargs)  # make bar plots

    h,l = axe.get_legend_handles_labels() # get the handles we want to modify
    for i in range(0, n_df * n_col, n_col): # len(h) = n_col * n_df
        for j, pa in enumerate(h[i:i+n_col]):
            for rect in pa.patches: # for each index
                rect.set_x(rect.get_x() + 1 / float(n_df + 1) * i / float(n_col))
                rect.set_hatch(H * int(i / n_col)) #edited part     
                rect.set_width(1 / float(n_df + 1))

    axe.set_xticks((np.arange(0, 2 * n_ind, 2) + 1 / float(n_df + 1)) / 2.)
    axe.set_xticklabels(df.index, rotation = 0)
    axe.set_title(title)

    # Add invisible data to add another legend
    n=[]        
    for i in range(n_df):
        n.append(axe.bar(0, 0, color="gray", hatch=H * i))

    l1 = axe.legend(h[:n_col], l[:n_col], loc=[1.01, 0.5])
    if labels is not None:
        l2 = plt.legend(n, labels, loc=[1.01, 0.1]) 
    axe.add_artist(l1)
    return axe
